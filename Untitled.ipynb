# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

# %%
df = pd.read_csv('heart_desease.csv')
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No               3
# 1           No  20.34      No              No    Yes               0
# 2           No  26.58     Yes              No     No              20
# 3           No  24.21      No              No     No               0
# 4           No  23.71      No              No     No              28
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0            30          No  Female        55-59  White      Yes
# 1             0          No  Female  80 or older  White       No
# 2            30          No    Male        65-69  White      Yes
# 3             0          No  Female        75-79  White       No
# 4             0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good          5    Yes            No        Yes
# ...

# %%
df_cat = df[["HeartDisease", "Smoking", "AlcoholDrinking", "DiffWalking", "Sex", "Race", "Diabetic", "PhysicalActivity", "GenHealth","Asthma", "KidneyDisease", "SkinCancer"]]
df_num = df[['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']]
df_cat
# Out:
#        HeartDisease Smoking AlcoholDrinking DiffWalking     Sex      Race  \
# 0                No     Yes              No          No  Female     White
# 1                No      No              No          No  Female     White
# 2                No     Yes              No          No    Male     White
# 3                No      No              No          No  Female     White
# 4                No      No              No         Yes  Female     White
# ...             ...     ...             ...         ...     ...       ...
# 319790          Yes     Yes              No         Yes    Male  Hispanic
# 319791           No     Yes              No          No    Male  Hispanic
# 319792           No      No              No          No  Female  Hispanic
# 319793           No      No              No          No  Female  Hispanic
# 319794           No      No              No          No  Female  Hispanic
#
#        Diabetic PhysicalActivity  GenHealth Asthma KidneyDisease SkinCancer
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  int64
#  6   MentalHealth      319795 non-null  int64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  int64
#  15  Asthma            319795 non-null  object
# ...

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
from sklearn.preprocessing import LabelEncoder
for i in df_cat.columns:
    le=LabelEncoder()
    label=le.fit_transform(df_cat[i])
    df_cat[i]=label
df_cat.head()
# Out:
#    HeartDisease  Smoking  AlcoholDrinking  DiffWalking  Sex  Race  Diabetic  \
# 0             0        1                0            0    0     5         2
# 1             0        0                0            0    0     5         0
# 2             0        1                0            0    1     5         2
# 3             0        0                0            0    0     5         0
# 4             0        0                0            1    0     5         0
#
#    PhysicalActivity  GenHealth  Asthma  KidneyDisease  SkinCancer
# 0                 1          4       1              0           1
# 1                 1          4       0              0           0
# 2                 1          1       1              0           0
# 3                 0          2       0              0           1
# 4                 1          4       0              0           0

# %%
data = pd.concat([df_cat, df_num], axis = 1)
data
# Out:
#         HeartDisease  Smoking  AlcoholDrinking  DiffWalking  Sex  Race  \
# 0                  0        1                0            0    0     5
# 1                  0        0                0            0    0     5
# 2                  0        1                0            0    1     5
# 3                  0        0                0            0    0     5
# 4                  0        0                0            1    0     5
# ...              ...      ...              ...          ...  ...   ...
# 319790             1        1                0            1    1     3
# 319791             0        1                0            0    1     3
# 319792             0        0                0            0    0     3
# 319793             0        0                0            0    0     3
# 319794             0        0                0            0    0     3
#
#         Diabetic  PhysicalActivity  GenHealth  Asthma  KidneyDisease  \
# ...

# %%
data.corr()
# Out:
#                   HeartDisease   Smoking  AlcoholDrinking  DiffWalking  \
# HeartDisease          1.000000  0.107764        -0.032080     0.201258
# Smoking               0.107764  1.000000         0.111768     0.120074
# AlcoholDrinking      -0.032080  0.111768         1.000000    -0.035328
# DiffWalking           0.201258  0.120074        -0.035328     1.000000
# Sex                   0.070040  0.085052         0.004200    -0.068860
# Race                  0.034854  0.065499         0.036702    -0.015831
# Diabetic              0.168553  0.053847        -0.057372     0.205502
# PhysicalActivity     -0.100030 -0.097174         0.017487    -0.278524
# GenHealth            -0.011062  0.020625         0.001629    -0.043552
# Asthma                0.041444  0.024149        -0.002202     0.103222
# KidneyDisease         0.145197  0.034920        -0.028280     0.153064
# SkinCancer            0.093317  0.033977        -0.005702     0.064840
# ...

# %%
data.drop(["BMI", "Race"], axis=1,  inplace =True)

# %%
data
# Out:
#         HeartDisease  Smoking  AlcoholDrinking  DiffWalking  Sex  Diabetic  \
# 0                  0        1                0            0    0         2
# 1                  0        0                0            0    0         0
# 2                  0        1                0            0    1         2
# 3                  0        0                0            0    0         0
# 4                  0        0                0            1    0         0
# ...              ...      ...              ...          ...  ...       ...
# 319790             1        1                0            1    1         2
# 319791             0        1                0            0    1         0
# 319792             0        0                0            0    0         0
# 319793             0        0                0            0    0         0
# 319794             0        0                0            0    0         0
#
# ...

# %%
x = data.drop('HeartDisease', axis=1)
y = data.HeartDisease
x
# Out:
#         Smoking  AlcoholDrinking  DiffWalking  Sex  Diabetic  \
# 0             1                0            0    0         2
# 1             0                0            0    0         0
# 2             1                0            0    1         2
# 3             0                0            0    0         0
# 4             0                0            1    0         0
# ...         ...              ...          ...  ...       ...
# 319790        1                0            1    1         2
# 319791        1                0            0    1         0
# 319792        0                0            0    0         0
# 319793        0                0            0    0         0
# 319794        0                0            0    0         0
#
#         PhysicalActivity  GenHealth  Asthma  KidneyDisease  SkinCancer  \
# 0                      1          4       1              0           1
# 1                      1          4       0              0           0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
pipeline_log_reg=Pipeline([('log_reg',LogisticRegression(random_state=42))])
pipeline_svc= Pipeline([('svc',LinearSVC(random_state=42))])
pipeline_Decison_Tree_Classifier= Pipeline([('Dt_classifier', DecisionTreeClassifier(random_state=42))])
pipeline_RFC= Pipeline([('RFC', RandomForestClassifier(random_state=42))])


pipelines = [pipeline_log_reg, pipeline_svc, pipeline_Decison_Tree_Classifier, pipeline_RFC]
pipe_dict = {0: "Logistic Regression", 1 : "SVC", 2 : "DTC", 3: "RFC"}

# %%
# pipeline_log_reg.fit(x_train,y_train)

# log_reg_pred =  pipeline_log_reg.predict(x_test)
# pipeline_log_reg.score(x_test, y_test)

# %%
len(x_train)
# Out:
# 223856

# %%
len(y_train)
# Out:
# 223856

# %%
# pipeline_svc.fit(x_train,y_train)

# svc_pred =  pipeline_svc.predict(x_test)
# print(svc_pred)
# pipeline_svc.score(x_test, y_test)

# %%
for pipes in pipelines:
    pipes.fit(x_train, y_train)

# %%
for i, model in enumerate(pipelines):
    cv_score = cross_val_score(model,x_train, y_train, cv=4)
    print(cv_score)
    print("%s: %f" %(pipe_dict[i], cv_score.mean()) )
# Out:
# [0.91496319 0.9138732  0.91442713 0.91442713]
# Logistic Regression: 0.914423
# [0.88539061 0.91462369 0.9147309  0.91476664]
# SVC: 0.907378
# [0.89471803 0.89359231 0.89268101 0.89386034]
# DTC: 0.893713
# [0.90677936 0.90529626 0.90531413 0.90463512]
# RFC: 0.905506

# %%
# from sklearn.metrics import confusion_matrix
# cm = confusion_matrix(y_test, log_reg_pred)
# cm

# %%
# import seaborn as sn
# plt.figure(figsize = (7,7))
# sn.heatmap(cm, annot=True)
# plt.xlabel('Predicted')
# plt.ylabel('Truth')

# %%
print("Training Accuracy of log_reg :", pipeline_log_reg.score(x_train, y_train))
print("Testing Accuracy log_reg:", pipeline_log_reg.score(x_test, y_test))
# Out:
# Training Accuracy of log_reg : 0.9144628689872061
# Testing Accuracy log_reg: 0.9129863767602331

# %%
print("Training Accuracy of svc:", pipeline_svc.score(x_train, y_train))
print("Testing Accuracy of svc :", pipeline_svc.score(x_test, y_test))
# Out:
# Training Accuracy of svc: 0.9147577013794582
# Testing Accuracy of svc : 0.9136117741481566

# %%
print("Training Accuracy of dtr:", pipeline_Decison_Tree_Classifier.score(x_train, y_train))
print("Testing Accuracy of dtr :", pipeline_Decison_Tree_Classifier.score(x_test, y_test))
# Out:
# Training Accuracy of dtr: 0.9486232220713315
# Testing Accuracy of dtr : 0.8930049302160747

# %%
print("Training Accuracy of RFC:",pipeline_RFC.score(x_train, y_train))
print("Testing Accuracy of RFC :",pipeline_RFC.score(x_test, y_test))
# Out:
# Training Accuracy of RFC: 0.9485964191265813
# Testing Accuracy of RFC : 0.9036679556801718
